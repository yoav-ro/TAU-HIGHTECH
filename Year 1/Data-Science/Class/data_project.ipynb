# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Imports the CSV file

# %%
full_file_path=(r"C:\Users\yoavr\Documents\GitHub\TAU-HIGHTECH\Year 1\Data-Science\Class\project_data.csv")
data_file= pd.read_csv(full_file_path)

# %% [markdown]
# Show data regarding age:

# %%
age_stats = data_file['age'].describe()

# Calculate mode separately
age_mode = data_file['age'].mode()[0]

# Create histograms and box plots for each variable
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Age
sns.histplot(data_file['age'], kde=True, ax=axes[0])
axes[0].set_title('Age Distribution - Histogram')
sns.boxplot(x=data_file['age'], ax=axes[1])
axes[1].set_title('Age Distribution - Box Plot')
# Out:
# Text(0.5, 1.0, 'Age Distribution - Box Plot')
